# %%
import tensorflow as tf
tf.__version__
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'Placeholder_21' with dtype float
# 	 [[{{node Placeholder_21}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-19-ed8bb2f6e065> in <module>
#       7 adder_node = tf.add(a,b)
#       8
# ----> 9 print(sess.run(adder_node), feed_dict = {a: 2.0 , b: 3.5})
#      10 print(sess.run(adder_node), feed_dict = {a: [2.0, 5.0], b: [3.0, 6.0]})
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'Placeholder_21' with dtype float
# 	 [[node Placeholder_21 (defined at C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'Placeholder_21':
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-19-ed8bb2f6e065>", line 6, in <module>
#     b = tf.placeholder(dtype = tf.float32)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\ops\array_ops.py", line 2619, in placeholder
#     return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py", line 6668, in placeholder
#     "Placeholder", dtype=dtype, shape=shape, name=name)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
#create node(constant)
hello = tf.constant("Hello, tensorFlow!")

#create session to run a node
sess = tf.Session()


#run the node using session, sess
print(sess.run(hello))
# Out:
# b'Hello, tensorFlow!'

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)
node3 = tf.add(node1,node2) # node3 = node1 + node2

# %%
print("node1:", node1, "node2:",node2)
print("node3:", node3)
#값을 출력하면 각 node의 metadata가 출력됨을 알 수 있다
# Out:
# node1: Tensor("Const_1:0", shape=(), dtype=float32) node2: Tensor("Const_2:0", shape=(), dtype=float32)
# node3: Tensor("Add:0", shape=(), dtype=float32)

# %%
sess = tf.Session()
print("sess.run(node1,node2):",sess.run([node1,node2]))
print("sess.run(node3)",sess.run(node3))
# Out:
# sess.run(node1,node2): [3.0, 4.0]
# sess.run(node3) 7.0

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'Placeholder_10' with dtype float
# 	 [[{{node Placeholder_10}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-14-d231e384163f> in <module>
#       3 adder_node = a + b
#       4
# ----> 5 print(sess.run(adder_node), feed_dict = {a: 2.0 , b: 3.5})
#       6 print(sess.run(adder_node), feed_dict = {a: [2.0, 5.0], b: [3.0, 6.0]})
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'Placeholder_10' with dtype float
# 	 [[node Placeholder_10 (defined at C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'Placeholder_10':
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\platform\asyncio.py", line 153, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-d231e384163f>", line 1, in <module>
#     a = tf.placeholder(dtype= tf.float32)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\ops\array_ops.py", line 2619, in placeholder
#     return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py", line 6668, in placeholder
#     "Placeholder", dtype=dtype, shape=shape, name=name)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\Maeg\Anaconda3\envs\Maeg\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
